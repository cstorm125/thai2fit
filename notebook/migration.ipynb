# %% [markdown]
# # Convert `fastai 0.7` Pretrained Weights to `fastai 1.0`

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import dill as pickle
from collections import Counter
from pathlib import Path
from sklearn.model_selection import train_test_split

from fastai.text import *
from pythainlp.ulmfit import *


DATA_PATH='../lm_data/'
MODEL_PATH = f'{DATA_PATH}models/'

# %%
data_lm = TextLMDataBunch.load(DATA_PATH,'qrnn_db',bs=64)

# %%
#heuristic reference from imdb_scripts
learn = language_model_learner(data_lm, bptt = 70, emb_sz = 300, nh = 1150, nl = 3,
                                  drop_mult = 0.3, bias = False,
                                  alpha=2, beta = 1)
learn.metrics = [accuracy]
learn.opt_func = partial(optim.Adam, betas=(0.8, 0.99))
learn.wd = 1e-7

# %%
new_wgts = learn.model.state_dict()
wgts = torch.load(f'{MODEL_PATH}thwiki_model_v02.pth', map_location=lambda storage, loc: storage)

# %%
#copy weights to new format
#encode
new_wgts['0.encoder.weight'] = wgts['0.encoder.weight']
new_wgts['0.encoder_dp.emb.weight'] = wgts['0.encoder_with_dropout.embed.weight']
#rnn0
new_wgts['0.rnns.0.weight_hh_l0_raw'] = wgts['0.rnns.0.module.weight_hh_l0_raw']
new_wgts['0.rnns.0.module.weight_ih_l0'] = wgts['0.rnns.0.module.weight_ih_l0']
new_wgts['0.rnns.0.module.weight_hh_l0'] = wgts['0.rnns.0.module.weight_hh_l0_raw']
new_wgts['0.rnns.0.module.bias_ih_l0'] = wgts['0.rnns.0.module.bias_ih_l0']
new_wgts['0.rnns.0.module.bias_hh_l0'] = wgts['0.rnns.0.module.bias_hh_l0']
#rnn1
new_wgts['0.rnns.1.weight_hh_l0_raw'] = wgts['0.rnns.1.module.weight_hh_l0_raw']
new_wgts['0.rnns.1.module.weight_ih_l0'] = wgts['0.rnns.1.module.weight_ih_l0']
new_wgts['0.rnns.1.module.weight_hh_l0'] = wgts['0.rnns.1.module.weight_hh_l0_raw']
new_wgts['0.rnns.1.module.bias_ih_l0'] = wgts['0.rnns.1.module.bias_ih_l0']
new_wgts['0.rnns.1.module.bias_hh_l0'] = wgts['0.rnns.1.module.bias_hh_l0']
#rnn2
new_wgts['0.rnns.2.weight_hh_l0_raw'] = wgts['0.rnns.2.module.weight_hh_l0_raw']
new_wgts['0.rnns.2.module.weight_ih_l0'] = wgts['0.rnns.2.module.weight_ih_l0']
new_wgts['0.rnns.2.module.weight_hh_l0'] = wgts['0.rnns.2.module.weight_hh_l0_raw']
new_wgts['0.rnns.2.module.bias_ih_l0'] = wgts['0.rnns.2.module.bias_ih_l0']
new_wgts['0.rnns.2.module.bias_hh_l0'] = wgts['0.rnns.2.module.bias_hh_l0']
#decode
new_wgts['1.decoder.weight'] = wgts['1.decoder.weight']

# %%
torch.save(new_wgts,f'{MODEL_PATH}thwiki_model_lstm.pth')

# %%
learn.load('thwiki_model_lstm')
# Out:
# LanguageLearner(data=TextLMDataBunch;
# Train: LabelList
# y: LMLabel (2049894 items)
# [0 0 0 0 ... 0 0 0 0]
# Path: .
# x: TextList (2049894 items)
# [list([5, 2, 3, 2, 479, 289, 4]) list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 183, 516, 596, 2214, 834, 21, 1877, 183, 516, 4524, 2, 742, 64, 9257, 7830, 2, 9038, 103, 132, 2, 235, 4])
#  ...
#  list([5, 2, 3, 2, 6, 26, 51, 2, 1302, 2, 13, 2750, 27, 499, 53, 646, 2, 37994, 2, 62, 905, 2, 28, 13, 2620, 1381, 27, 26, 51, 2, 2151, 2, 7, 13, 2750, 2, 26710, 2, 62, 4])
#  list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 20, 2, 12, 2, 22, 35, 4])]
# Path: ../lm_data;
# Valid: LabelList
# y: LMLabel (20706 items)
# [0 0 0 0 ... 0 0 0 0]
# Path: .
# x: TextList (20706 items)
# [list([5, 2, 3, 2, 134, 71, 6, 26, 51, 2, 22917, 2, 33, 874, 7, 13, 1005, 55, 258, 91, 77, 252, 2221, 2, 12380, 14, 1012, 250, 166, 135, 280, 2, 28, 38, 55, 7745, 2, 6, 26, 2, 51, 2, 10210, 2, 208, 7594, 144, 1555, 9171, 441, 2, 954, 324, 6870, 2, 6127, 6460, 38, 404, 31, 2152, 663, 6, 4772, 7, 116, 130, 25, 1783, 2, 27809, 926, 7, 64, 29, 17098, 97, 185, 6118, 53, 9, 11527, 68, 286, 3202, 1891, 97, 185, 1108, 2, 840, 42, 1725, 38, 348, 5022, 6, 26, 2, 51, 2, 23359, 2, 6, 2802, 6, 1584, 1215, 90, 159, 77, 175, 94, 164, 77, 2, 17, 14605, 2, 351, 2, 0, 18, 2, 7, 336, 166, 97, 185, 6118, 2, 1555, 2, 250, 72, 280, 2, 2601, 967, 607, 70, 543, 10, 475, 7, 6101, 2, 14239, 2, 419, 2, 17, 10213, 18, 2, 2803, 10, 1528, 1806, 5026, 159, 7, 82, 1147, 1588, 273, 1067, 2108, 6, 15, 533, 1711, 52, 2, 712, 2, 8, 70, 4318, 10, 7745, 2, 17, 1783, 18, 2, 110, 874, 14, 2601, 2803, 10, 475, 336, 7, 833, 2, 28, 411, 534, 9, 663, 7, 58, 64, 72, 2547, 1118, 784, 83, 107, 25, 9, 70, 54024, 102, 668, 10, 7745, 8, 1528, 6, 1197, 1887, 4])
#  list([5, 2, 3, 2, 175, 77, 169, 155, 4040, 102, 193, 77, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 20, 2, 12, 2, 22, 35, 4]) ...
#  list([5, 2, 3, 2, 20, 22, 2, 43, 16, 0, 11, 2, 49, 16, 45, 32, 2, 12, 2, 12, 2, 41, 19, 48, 19, 44, 2, 12, 2, 46, 40, 50, 37, 0, 11, 2, 47, 16, 287, 289, 687, 0, 4])
#  list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 899, 562, 449, 7, 64, 556, 91, 28644, 24, 417, 2, 38531, 2, 1908, 2, 4])]
# Path: ../lm_data;
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(60002, 300, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(60002, 300, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(300, 1150)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 300)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=300, out_features=60002, bias=False)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.8, 0.99)), loss_func=<function cross_entropy at 0x7f264e024620>, metrics=[<function accuracy at 0x7f264de392f0>], true_wd=True, bn_wd=True, wd=1e-07, train_bn=True, path=PosixPath('../lm_data'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[RNNTrainer(learn=LanguageLearner(data=TextLMDataBunch;
# Train: LabelList
# y: LMLabel (2049894 items)
# [0 0 0 0 ... 0 0 0 0]
# Path: .
# x: TextList (2049894 items)
# [list([5, 2, 3, 2, 479, 289, 4]) list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 183, 516, 596, 2214, 834, 21, 1877, 183, 516, 4524, 2, 742, 64, 9257, 7830, 2, 9038, 103, 132, 2, 235, 4])
#  ...
#  list([5, 2, 3, 2, 6, 26, 51, 2, 1302, 2, 13, 2750, 27, 499, 53, 646, 2, 37994, 2, 62, 905, 2, 28, 13, 2620, 1381, 27, 26, 51, 2, 2151, 2, 7, 13, 2750, 2, 26710, 2, 62, 4])
#  list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 20, 2, 12, 2, 22, 35, 4])]
# Path: ../lm_data;
# Valid: LabelList
# y: LMLabel (20706 items)
# [0 0 0 0 ... 0 0 0 0]
# Path: .
# x: TextList (20706 items)
# [list([5, 2, 3, 2, 134, 71, 6, 26, 51, 2, 22917, 2, 33, 874, 7, 13, 1005, 55, 258, 91, 77, 252, 2221, 2, 12380, 14, 1012, 250, 166, 135, 280, 2, 28, 38, 55, 7745, 2, 6, 26, 2, 51, 2, 10210, 2, 208, 7594, 144, 1555, 9171, 441, 2, 954, 324, 6870, 2, 6127, 6460, 38, 404, 31, 2152, 663, 6, 4772, 7, 116, 130, 25, 1783, 2, 27809, 926, 7, 64, 29, 17098, 97, 185, 6118, 53, 9, 11527, 68, 286, 3202, 1891, 97, 185, 1108, 2, 840, 42, 1725, 38, 348, 5022, 6, 26, 2, 51, 2, 23359, 2, 6, 2802, 6, 1584, 1215, 90, 159, 77, 175, 94, 164, 77, 2, 17, 14605, 2, 351, 2, 0, 18, 2, 7, 336, 166, 97, 185, 6118, 2, 1555, 2, 250, 72, 280, 2, 2601, 967, 607, 70, 543, 10, 475, 7, 6101, 2, 14239, 2, 419, 2, 17, 10213, 18, 2, 2803, 10, 1528, 1806, 5026, 159, 7, 82, 1147, 1588, 273, 1067, 2108, 6, 15, 533, 1711, 52, 2, 712, 2, 8, 70, 4318, 10, 7745, 2, 17, 1783, 18, 2, 110, 874, 14, 2601, 2803, 10, 475, 336, 7, 833, 2, 28, 411, 534, 9, 663, 7, 58, 64, 72, 2547, 1118, 784, 83, 107, 25, 9, 70, 54024, 102, 668, 10, 7745, 8, 1528, 6, 1197, 1887, 4])
#  list([5, 2, 3, 2, 175, 77, 169, 155, 4040, 102, 193, 77, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 20, 2, 12, 2, 22, 35, 4]) ...
#  list([5, 2, 3, 2, 20, 22, 2, 43, 16, 0, 11, 2, 49, 16, 45, 32, 2, 12, 2, 12, 2, 41, 19, 48, 19, 44, 2, 12, 2, 46, 40, 50, 37, 0, 11, 2, 47, 16, 287, 289, 687, 0, 4])
#  list([5, 2, 3, 2, 4]) list([5, 2, 3, 2, 4])
#  list([5, 2, 3, 2, 899, 562, 449, 7, 64, 556, 91, 28644, 24, 417, 2, 38531, 2, 1908, 2, 4])]
# Path: ../lm_data;
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(60002, 300, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(60002, 300, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(300, 1150)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 300)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=300, out_features=60002, bias=False)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.8, 0.99)), loss_func=<function cross_entropy at 0x7f264e024620>, metrics=[<function accuracy at 0x7f264de392f0>], true_wd=True, bn_wd=True, wd=1e-07, train_bn=True, path=PosixPath('../lm_data'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[...], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(300, 1150)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 300)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(60002, 300, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60002, 300, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=300, out_features=60002, bias=False)
#     (output_dp): RNNDropout()
#   )
# )]), bptt=70, alpha=2, beta=1, adjust=False)], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(300, 1150)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 300)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(60002, 300, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60002, 300, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=300, out_features=60002, bias=False)
#     (output_dp): RNNDropout()
#   )
# )])

# %%
#new weight merging function
def merge_wgts(em_sz, wgts, itos_pre, itos_cls):
    vocab_size = len(itos_cls)
    enc_wgts = to_np(wgts['0.encoder.weight'])
    #average weight of encoding
    row_m = enc_wgts.mean(0)
    stoi_pre = collections.defaultdict(lambda:-1, {v:k for k,v in enumerate(itos_pre)})
    #new embedding based on classification dataset
    new_w = np.zeros((vocab_size, em_sz), dtype=np.float32)
    for i,w in enumerate(itos_cls):
        r = stoi_pre[w]
        #use pretrianed embedding if present; else use the average
        new_w[i] = enc_wgts[r] if r>=0 else row_m
    wgts['0.encoder.weight'] = T(new_w)
    wgts['0.encoder_dp.embed.weight'] = T(np.copy(new_w))
    wgts['1.decoder.weight'] = T(np.copy(new_w))
    return(wgts)

# %%
#replace tokens with new version
itos_lstm = pickle.load(open(f'{MODEL_PATH}itos_lstm.pkl','rb'))
itos_lstm[0] = 'xxunk'
itos_lstm[1] = 'xxpad'
itos_lstm[6] = 'xxfld'
itos_lstm[3661] = 'xxrep'
pickle.dump(itos_lstm,open(f'{MODEL_PATH}itos_lstm.pkl','wb'))

# %%
itos_lstm
# Out:
# ['xxunk',
#  'xxpad',
#  ' ',
#  'ใน',
#  'ที่',
#  'และ',
#  'xxfld',
#  'เป็น',
#  'ของ',
#  'มี',
#  'ได้',
#  '"',
#  'การ',
#  '(',
#  ')',
#  'โดย',
#  'กับ',
#  'ส',
#  'จะ',
#  'ปี',
#  'ว่า',
#  'จาก',
#  ',',
#  'ให้',
#  'ซึ่ง',
#  'พ.ศ.',
#  'ไป',
#  '.',
#  'เมื่อ',
#  '-',
#  'มา',
#  'อ',
#  'น',
#  'พระ',
#  'ก็',
#  'หรือ',
#  'อยู่',
#  '์',
#  'นี้',
#  'คือ',
#  'ร์',
#  'แต่',
#  'ใช้',
#  'ค.ศ.',
#  '/',
#  'ยัง',
#  'ด้วย',
#  'เขา',
#  'คน',
#  'วันที่',
#  'ถูก',
#  'ไม่',
#  'แห่ง',
#  'เพื่อ',
#  'ๆ',
#  'จึง',
#  'ทาง',
#  'ขึ้น',
#  '2',
#  ':',
#  'ได้รับ',
#  'นั้น',
#  '1',
#  'สามารถ',
#  'ผู้',
#  'แล้ว',
#  'เมือง',
#  'ล',
#  'ทำให้',
#  '3',
#  'กัน',
#  'ประเทศ',
#  'ถึง',
#  'ทรง',
#  'เธอ',
#  'ชื่อ',
#  'หนึ่ง',
#  'เรื่อง',
#  'เพลง',
#  'ริ',
#  'สร้าง',
#  'ออก',
#  'ตาม',
#  'ต่อ',
#  'เกิด',
#  'ท',
#  'ต้อง',
#  'แบบ',
#  'ไทย',
#  'อีก',
#  'ทั้ง',
#  'ระหว่าง',
#  'ต่อมา',
#  'จังหวัด',
#  'นา',
#  'พระองค์',
#  'ส่วน',
#  'มิ',
#  'ความ',
#  'ทำ',
#  'ปัจจุบัน',
#  '4',
#  'แรก',
#  'เช่น',
#  'ลง',
#  'มาก',
#  'สำหรับ',
#  'กลุ่ม',
#  'ด้าน',
#  'ทีม',
#  'เรียก',
#  'พบ',
#  'รา',
#  'เอ',
#  'ตัว',
#  'อย่าง',
#  'ใหม่',
#  '%',
#  'ช',
#  'วัน',
#  '5',
#  'ณ',
#  'เริ่ม',
#  'โรงเรียน',
#  'หลาย',
#  'เดือน',
#  'ไว้',
#  'เข้า',
#  'พระเจ้า',
#  'จน',
#  'ชาว',
#  'วัด',
#  'of',
#  'บน',
#  'จัด',
#  'ที่สุด',
#  'ช่วง',
#  'ครั้ง',
#  'รี',
#  'ซี',
#  'ภาษา',
#  'ตั้งแต่',
#  'ราช',
#  'นิ',
#  'โอ',
#  'ดี',
#  'ลิ',
#  'นำ',
#  'กว่า',
#  'สมเด็จ',
#  'ภาพยนตร์',
#  'เด',
#  'ลา',
#  'อำเภอ',
#  'สี',
#  'ที่จะ',
#  'เต',
#  'โลก',
#  'มาจาก',
#  'เล่น',
#  'ซา',
#  'จำนวน',
#  'กา',
#  'ก',
#  'ซิ',
#  'อา',
#  'ระดับ',
#  'ต่าง',
#  '8',
#  'โร',
#  'งาน',
#  'นาย',
#  'ยา',
#  'เม',
#  'สอง',
#  'วิ',
#  'คำ',
#  'เพราะ',
#  '6',
#  'ต',
#  'มหาวิทยาลัย',
#  'รัฐ',
#  'ทั้งหมด',
#  'อาจ',
#  'เซ',
#  'ก่อน',
#  'ว',
#  '“',
#  'มัน',
#  'ค',
#  'ใหญ่',
#  'เนื่องจาก',
#  'ตา',
#  'ชุด',
#  'ประมาณ',
#  'การแข่งขัน',
#  'บริษัท',
#  'คา',
#  'the',
#  'นัก',
#  'หลัง',
#  'ระบบ',
#  'อัลบั้ม',
#  'ประเทศไทย',
#  'ร',
#  'อัน',
#  'สมัย',
#  'ชิ',
#  'บ้าน',
#  '7',
#  'เท',
#  'เขต',
#  'เพียง',
#  'โก',
#  'เกิดขึ้น',
#  'หน้า',
#  'พื้นที่',
#  '–',
#  "'",
#  'เวลา',
#  'ลักษณะ',
#  'รวม',
#  'บริเวณ',
#  'อื่น',
#  'ไม่มี',
#  'ผ่าน',
#  '”',
#  'แก่',
#  'เคย',
#  'ลี',
#  'ตำแหน่ง',
#  'โค',
#  'เปิด',
#  'หลังจาก',
#  'ได้แก่',
#  'กรุง',
#  'บาง',
#  'เดิม',
#  'เจ้า',
#  'องค์',
#  'The',
#  'ฝ่าย',
#  'ด',
#  'เกม',
#  '10',
#  'รายการ',
#  'ประกาศ',
#  'การศึกษา',
#  'สำคัญ',
#  'ปลา',
#  'อันดับ',
#  'แสดง',
#  'ตำบล',
#  'สูง',
#  'รอบ',
#  'ไม่ได้',
#  'จิ',
#  'โต',
#  'เหตุการณ์',
#  'ต่างๆ',
#  '9',
#  'ภาค',
#  'ล้าน',
#  'โน',
#  'ชนิด',
#  'รับ',
#  'เกี่ยวกับ',
#  'ตั้งอยู่',
#  'ดิ',
#  'กลับ',
#  'รุ่น',
#  'ฟุตบอล',
#  'ผลงาน',
#  'เก',
#  'คณะ',
#  'เทพ',
#  'ญี่ปุ่น',
#  'รัฐบาล',
#  'อดีต',
#  'อังกฤษ',
#  'สุ',
#  'น้ำ',
#  'ท่าน',
#  'ฟ',
#  'ต์',
#  'ยาว',
#  'สาย',
#  'ฝรั่งเศส',
#  'เป็นการ',
#  'ภาพ',
#  'บ',
#  'ส่ง',
#  'ช่วย',
#  'หลัก',
#  '\xa0',
#  'ป',
#  'and',
#  'บา',
#  '0',
#  'ก็ได้',
#  'ชาติ',
#  'ติ',
#  'พรรค',
#  'ตอน',
#  'ร่วม',
#  'อี',
#  'ชั้น',
#  'โม',
#  'ดังกล่าว',
#  'ยุค',
#  'ภายใน',
#  'เห็น',
#  'จีน',
#  'ดู',
#  'ออกมา',
#  'ดา',
#  'สาม',
#  'วง',
#  'ครั้งแรก',
#  'เปลี่ยน',
#  'รูป',
#  'สโมสร',
#  'ช่อง',
#  'มากกว่า',
#  'แอ',
#  'เดียว',
#  'กำลัง',
#  'คอ',
#  'เป',
#  'จนถึง',
#  'สงคราม',
#  'แบ่ง',
#  'โด',
#  'ฉบับ',
#  'ธ',
#  'วา',
#  'รูปแบบ',
#  'ข้อมูล',
#  'นอกจากนี้',
#  'กลาง',
#  'เขียน',
#  'ตั้ง',
#  'เอง',
#  'ออ',
#  'ศึกษา',
#  'วงศ์',
#  '20',
#  'ลด',
#  'เข้ามา',
#  'ฮา',
#  'เร',
#  'ยู',
#  '12',
#  'บาท',
#  'มหา',
#  'พวก',
#  'อะ',
#  'หมายถึง',
#  'ม',
#  'ถนน',
#  '",',
#  'ย์',
#  'ระ',
#  'แทน',
#  'ในประเทศ',
#  'B',
#  'วี',
#  'ผล',
#  'ธันวาคม',
#  'http',
#  'ตุลาคม',
#  'รางวัล',
#  'ทอง',
#  'ตน',
#  'นาง',
#  'ปรากฏ',
#  'มีนาคม',
#  'เกาะ',
#  'โซ',
#  'พฤษภาคม',
#  'ประเภท',
#  'มนุษย์',
#  'ทา',
#  'ใต้',
#  'ชาย',
#  'เสียง',
#  'เดียวกัน',
#  'จักรพรรดิ',
#  'ทุก',
#  'เมษายน',
#  'ย',
#  'สุดท้าย',
#  'กันยายน',
#  'ขนาด',
#  'แนว',
#  'ออกจาก',
#  'ง',
#  'โล',
#  'กองทัพ',
#  'พัฒนา',
#  'มกราคม',
#  'ประกอบ',
#  'ชา',
#  'สิงหาคม',
#  '=',
#  'เดินทาง',
#  '15',
#  'ทหาร',
#  'เท่านั้น',
#  'สมาชิก',
#  'ชนะ',
#  'ทั้งสอง',
#  'www',
#  'สาขา',
#  'กลายเป็น',
#  'ประชาชน',
#  '),',
#  'เลือก',
#  'ลีก',
#  'แต่ละ',
#  'อายุ',
#  'ศรี',
#  'อีกครั้ง',
#  'รัก',
#  'กีฬา',
#  'ลูก',
#  'ซ์',
#  'เล็ก',
#  'พวกเขา',
#  'ประกอบด้วย',
#  'ขอ',
#  'พฤศจิกายน',
#  'สหรัฐอเมริกา',
#  'com',
#  'หญิง',
#  'อาหาร',
#  'พา',
#  'กรกฎาคม',
#  'น้อย',
#  'เพิ่ม',
#  'มิถุนายน',
#  'ซู',
#  'ถ้า',
#  'ไอ',
#  'ราชวงศ์',
#  'หา',
#  'สิ่ง',
#  'เหนือ',
#  'ส่วนใหญ่',
#  'ตี',
#  'E',
#  'ผลิต',
#  'เจ',
#  'สู่',
#  'ที่อยู่',
#  'อาศัย',
#  'ย้าย',
#  'ชื่อว่า',
#  'มัก',
#  '16',
#  'รู',
#  'ฐานะ',
#  '11',
#  'อาคาร',
#  'เดอะ',
#  'กุมภาพันธ์',
#  'ฤดูกาล',
#  'มะ',
#  'จบ',
#  'แม่',
#  'เลย',
#  'แห่งชาติ',
#  'รวมทั้ง',
#  'อาร์',
#  'ประจำ',
#  '30',
#  'จากนั้น',
#  'รวมถึง',
#  'อิ',
#  'หนังสือ',
#  'กลับมา',
#  'A',
#  'ดาว',
#  'พระราชทาน',
#  'ออกอากาศ',
#  'ร่วมกับ',
#  'เด็ก',
#  'ชีวิต',
#  'กำหนด',
#  'ทั่วไป',
#  'สัตว์',
#  '14',
#  'คู่',
#  'กิ',
#  'in',
#  'กะ',
#  'เครื่อง',
#  'อิน',
#  'บุคคล',
#  'เฮ',
#  'การแสดง',
#  '18',
#  'แม่น้ำ',
#  'เรา',
#  'ห',
#  'คล้าย',
#  'อง',
#  'มาร',
#  'ดังนี้',
#  'ปา',
#  'นี',
#  'เอา',
#  'สนับสนุน',
#  'เสด็จ',
#  'เรือ',
#  'เล่ม',
#  ';',
#  'ทำงาน',
#  'ใบ',
#  'โท',
#  'แมน',
#  'หัว',
#  'เข้าร่วม',
#  'เข้าไป',
#  'เสียชีวิต',
#  'กอ',
#  '_',
#  'ภายใต้',
#  'รอ',
#  'บุตร',
#  'ชัย',
#  'ชัน',
#  'ที',
#  '13',
#  'ตัน',
#  'โบ',
#  'เป็นต้น',
#  'บท',
#  'พิเศษ',
#  'นับ',
#  'ขาว',
#  'นก',
#  'โครงการ',
#  'หลวง',
#  'โรค',
#  'เล',
#  'คริสต์',
#  'มอ',
#  'นท',
#  'ยังคง',
#  'ควบคุม',
#  'สาร',
#  'ขนาดใหญ่',
#  '19',
#  'จำหน่าย',
#  'จำกัด',
#  'กร',
#  'จุด',
#  'สถาบัน',
#  's',
#  'เงิน',
#  'อีกด้วย',
#  '17',
#  'นิยม',
#  'วิทยาลัย',
#  'การปกครอง',
#  'ยุ',
#  'มักจะ',
#  'หลังจากนั้น',
#  'ประชากร',
#  'สัน',
#  'อาจจะ',
#  'ไซ',
#  'นักแสดง',
#  'จนกระทั่ง',
#  'เมตร',
#  'แยก',
#  'ยะ',
#  'อื่นๆ',
#  'ศตวรรษ',
#  '25',
#  'พอ',
#  'ประวัติศาสตร์',
#  'น.',
#  'หาก',
#  'นะ',
#  'ดนตรี',
#  'เพื่อให้',
#  'ภายหลัง',
#  'นัด',
#  'ตนเอง',
#  'เจ้าชาย',
#  'ด์',
#  'คิด',
#  'กิน',
#  'ชิง',
#  'การเลือกตั้ง',
#  'เหล่านี้',
#  'ไท',
#  'ปลาย',
#  'บี',
#  'จัดตั้ง',
#  'เซอร์',
#  'สกุล',
#  'อาการ',
#  'เหมือน',
#  'คณะกรรมการ',
#  'บิดา',
#  'ดำรงตำแหน่ง',
#  'ก่อตั้ง',
#  'ห้อง',
#  'อุ',
#  'ต้น',
#  'จา',
#  'ละคร',
#  'หน่วย',
#  '(;',
#  'สหรัฐ',
#  '".',
#  'ตระกูล',
#  'สูงสุด',
#  'สังคม',
#  'ตัวเอง',
#  'ดังนั้น',
#  'ที่สอง',
#  'จำนวนมาก',
#  '&',
#  'ตะวันออก',
#  'เจอ',
#  'ตรง',
#  'นักร้อง',
#  'รักษา',
#  '")',
#  'สภา',
#  'เอส',
#  'เข้าสู่',
#  'ดอน',
#  'เซลล์',
#  'พยายาม',
#  'เจ้าหญิง',
#  'เส้น',
#  'ศิลปิน',
#  'บิน',
#  'ครู',
#  'ครอบครัว',
#  'เค',
#  'อักษร',
#  'โดยเฉพาะ',
#  'ยุโรป',
#  'นักเรียน',
#  'ดำ',
#  'เน',
#  'แปล',
#  'สมาคม',
#  '24',
#  'เพ',
#  'ราว',
#  '21',
#  'แตก',
#  'ใกล้',
#  'กุ',
#  'ศูนย์',
#  'รุ',
#  'ต่อไป',
#  'พี',
#  'ต้องการ',
#  'ออกแบบ',
#  'ละ',
#  'สิ',
#  'เวอร์',
#  'ยก',
#  'ซ',
#  'พัน',
#  'รัสเซีย',
#  'มากมาย',
#  'จี',
#  'อาณาจักร',
#  'ธรรม',
#  'สถานี',
#  'เป็นหนึ่ง',
#  'การพัฒนา',
#  'สังกัด',
#  'นคร',
#  'ท่า',
#  'p',
#  'แสง',
#  'รถ',
#  'แชมป์',
#  'ติด',
#  'ป่า',
#  'เรียน',
#  'กู',
#  'เสีย',
#  'พม่า',
#  'สนาม',
#  'ยิง',
#  'ดินแดน',
#  'พร้อมกับ',
#  'เทคโนโลยี',
#  'ปกครอง',
#  'ทะเล',
#  '""',
#  'คุ',
#  'นาน',
#  'แม้',
#  'บิ',
#  'แผ่นดิน',
#  'ซิงเกิล',
#  'เบ',
#  ').',
#  'วิน',
#  'สาธารณรัฐ',
#  'to',
#  'แดง',
#  'มากขึ้น',
#  'กษัตริย์',
#  'สถานที่',
#  'โย',
#  'สยาม',
#  'อำนาจ',
#  'หลังจากที่',
#  'ไฟ',
#  'โอลิมปิก',
#  'สี่',
#  'ประตู',
#  'ยอด',
#  'ใด',
#  'ในขณะที่',
#  'วอ',
#  'เชื่อ',
#  'ค่าย',
#  'วิหาร',
#  'คะแนน',
#  'แพ้',
#  'ทำการ',
#  'ป้องกัน',
#  'ฮ',
#  'แต่งตั้ง',
#  'วัง',
#  'ได',
#  'อาชีพ',
#  'รัฐมนตรี',
#  'บันทึก',
#  'เอเชีย',
#  'ฉาย',
#  'มุ',
#  'อย่างไรก็ตาม',
#  'ห์',
#  'วิชา',
#  'มีชื่อเสียง',
#  'เยอรมนี',
#  'กรุงเทพมหานคร',
#  'พระนาง',
#  'วิธี',
#  'อก',
#  'กิโลเมตร',
#  'เซน',
#  'พล',
#  'โฮ',
#  'วาง',
#  '2551',
#  'ส่วนหนึ่ง',
#  '22',
#  'ใส่',
#  'พ่อ',
#  'ความสามารถ',
#  'เฟ',
#  'เลอ',
#  'หมู่บ้าน',
#  'ข้าง',
#  'ชน',
#  'นอ',
#  'พืช',
#  'หมู่',
#  'ขาย',
#  'จักรวรรดิ',
#  'ชก',
#  'บอ',
#  'องค์กร',
#  'แก้ว',
#  'สอน',
#  'a',
#  'ประธาน',
#  'ก่อสร้าง',
#  '23',
#  'ครั้งนี้',
#  'ตะวันตก',
#  'ราย',
#  'เฉพาะ',
#  'ก่อ',
#  'ตาย',
#  'ขนาดเล็ก',
#  'ชี',
#  'สิทธิ',
#  'รู้จัก',
#  'รัชกาล',
#  'เลือด',
#  'รับรางวัล',
#  'ฐาน',
#  'ว์',
#  'ตรา',
#  'ทำลาย',
#  'ชอบ',
#  'พลัง',
#  'พระยา',
#  'พร้อม',
#  'จู',
#  'รอง',
#  'เดิน',
#  'ศักดิ์',
#  'th',
#  'วัฒนธรรม',
#  'ศิลปะ',
#  'เกิน',
#  'โจมตี',
#  'ตะ',
#  'แผ่น',
#  'พ',
#  'สาว',
#  'หลักสูตร',
#  'กล่าว',
#  '2550',
#  'เป็นที่รู้จัก',
#  'เปิดตัว',
#  'พันธุ์',
#  'แข่งขัน',
#  'กรม',
#  'ศาสนา',
#  'รายชื่อ',
#  'เริ่มต้น',
#  'ไม้',
#  'ตัวละคร',
#  'พลังงาน',
#  'ทำหน้าที่',
#  'ค่า',
#  'เบอร์',
#  'ในที่สุด',
#  'นาม',
#  '26',
#  'หิน',
#  '100',
#  'จัดการ',
#  'ต่างกัน',
#  'อาจารย์',
#  'อิตาลี',
#  'กอง',
#  '27',
#  'ย่อย',
#  'วิทยาศาสตร์',
#  'แถบ',
#  'บุ',
#  'ดอก',
#  'กี',
#  'กล่าวว่า',
#  'กำกับ',
#  'ขณะที่',
#  'นี่',
#  'สัญลักษณ์',
#  'เหลือ',
#  '2012',
#  'เรื่องราว',
#  'สุด',
#  'เกี่ยวข้อง',
#  'ปัญหา',
#  'โพ',
#  'โบราณ',
#  'ทำให้เกิด',
#  'เยอรมัน',
#  'ใกล้เคียง',
#  'ดำเนินการ',
#  'ธง',
#  'ยึด',
#  'สหราชอาณาจักร',
#  'โรงพยาบาล',
#  '28',
#  'ระบุ',
#  'คลอง',
#  'ลำ',
#  'คุณ',
#  'เชียงใหม่',
#  '2555',
#  'ประสบความสำเร็จ',
#  '29',
#  'สภาพ',
#  'คาร์',
#  'ตลอด',
#  'พร',
#  'อินเดีย',
#  'เป็นครั้งแรก',
#  'ลำดับ',
#  'การผลิต',
#  'โทรทัศน์',
#  'อัล',
#  'ผู้นำ',
#  'รู้',
#  'การ์ตูน',
#  'จุฬา',
#  'ดูแล',
#  'โจ',
#  'ธุรกิจ',
#  'ภาษาอังกฤษ',
#  'ร่างกาย',
#  'ความสัมพันธ์',
#  'วะ',
#  'นายกรัฐมนตรี',
#  'เนอ',
#  'กฎหมาย',
#  'แม้ว่า',
#  'ฟ้า',
#  'ต่อต้าน',
#  '2008',
#  'บรม',
#  'เช่นกัน',
#  'เก็บ',
#  'เก่า',
#  'มณฑล',
#  'พิธี',
#  'วงการ',
#  'บุญ',
#  'สำนักงาน',
#  'พระราชินี',
#  'เป็นเวลา',
#  'ซะ',
#  'ข่าว',
#  'เดน',
#  'บอก',
#  'ปล่อย',
#  'เอก',
#  'แก',
#  'เพื่อน',
#  'เบล',
#  'นุ',
#  'นิตยสาร',
#  'ชู',
#  'ว่าการ',
#  'สั้น',
#  'กว้าง',
#  'เย',
#  'หน้าที่',
#  'ไว',
#  'จอห์น',
#  'เจริญ',
#  'ทั่วโลก',
#  'พระนาม',
#  'แค',
#  '("',
#  'แหล่ง',
#  'คิ',
#  'อู',
#  'ไม่ใช่',
#  'ถือว่า',
#  'ร่วมกัน',
#  'เหล่า',
#  'ธรรมชาติ',
#  'เส้นทาง',
#  'เครื่องบิน',
#  'การทำงาน',
#  'นำมา',
#  'ขยาย',
#  'ดัง',
#  'เอฟ',
#  'ดำเนิน',
#  'ชิน',
#  'จริง',
#  'อย่างเป็นทางการ',
#  'ดิน',
#  'เวียดนาม',
#  'การบริหาร',
#  'ด้วยกัน',
#  '2554',
#  '2552',
#  'กุล',
#  'ถือเป็น',
#  'แต่ง',
#  'โป',
#  'หมายเลข',
#  'หลักฐาน',
#  'ปาก',
#  '?',
#  '2556',
#  'น่า',
#  'โครงสร้าง',
#  'ปกติ',
#  'คอน',
#  'เชิง',
#  'สวน',
#  'ข้อ',
#  'ปราสาท',
#  'สม',
#  'ดร.',
#  'แอน',
#  'นอก',
#  'อาวุธ',
#  'ล่า',
#  'บางครั้ง',
#  'เพิ่มขึ้น',
#  'พระมหากษัตริย์',
#  '2010',
#  'ขณะ',
#  '\u200b',
#  ...]
